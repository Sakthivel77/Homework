# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-29f95b45-f5af-4e4e-91d2-1def2dd025ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29f95b45-f5af-4e4e-91d2-1def2dd025ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.data to iris.data

# %% [markdown]
# # Exercise 8
#
# Related Notes:
# - Fundamentals_5 File IO

# %% [markdown]
# ## Exercise 8.1
#
# Write following list `s` into a text file `q1.txt` with each item occupying 1 line.
#
# >```python
# >s = [chr(i) + '.txt' for i in range(ord('A'), ord('F'))]
# >```
#
# Use following command in Jupyter Notebook to open `q1.txt` to verify the content in the file.
#
# >`!notepad q1.txt`

# %%
s = [chr(i) + '.txt' for i in range(ord('A'), ord('F'))]
print(s)
# Out:
# ['A.txt', 'B.txt', 'C.txt', 'D.txt', 'E.txt']

# %%
with open('q1.txt','w') as f:
  for i in s:
    f.write(i+'\n')

# %% [markdown]
# import os
# if os.path.exists(file_path): pass## Exercise 8.2
#
# For each line of text in `q1.txt`, generate an empty text file and name the file using that line of text. If file already exists, remove it before generate new file.
#
# Use following code to check if a file exists.
#
# >```python
# >import os
# >if os.path.exists(file_path): pass
# >```
#
# Use following command in Jupyter Notebook to confirm that you have generated all files.
#
# >```bash
# >!ls *.txt
# >```

# %%
import os


with open('q1.txt','r') as f:
  for filename in f.readlines():
    fn = filename.rstrip()
    if os.path.exists(fn):
       os.remove(fn)
    with open(fn,'w') as f1:
      pass

# %% [markdown]
# ## Exercise 8.3
#
# Write code to generate all the positive integers up to $n$ that are perfect squares and save them in a text file called `PERFECT_SQUARES.TXT`. Note that each line within the file should contain one integer, and the last character within the file should be an end line character.

# %%
n = 99
def perfectSq(n):
  return [x**2 for x in range(0,int(n**0.5)+1)]
with open('PERFECT_SQUARES.TXT','w') as f:
  for ps in perfectSq(n):
    f.write(str(ps)+'\n')

# %% [markdown]
# ## Exercise 8.4
#
# Write code to generate all the positive integers from $n + 1$ to $n + m$, and then append them to the file used in question 1. (Note, do not overwrite the perfect squares from Question 1.)

# %%
m = 28
with open('PERFECT_SQUARES.TXT','a') as f:
  for i in range(n+1,n+m+1):
    f.write(str(i)+'\n')

# %% [markdown]
# ## Exercise 8.5
#
# A log of a certain boss fight from a certain game is stored inside the file `log_ex8.csv` under the folder `resources`. The csv file contains the following header.
#
# - `'Parse%'`  refers to the performance of the character relative to all other players in the world,
# - `'Name'` refers to the name of the character in the game,
# - `'Amount'`  refers to the amount of damage
# - `'iLvL'`  refers to the quality of the equipment the character is using,
# - `'iLvL%'` refers to the performance of the player relative to players with similar quality of equipment,
# - `'Active Time'` refers to the percentage of time spend by the character doing damage during the fight.
# - `'DPS'` refers to the amount of damage done per second in the fight.
#
# Your task is to:
#
# - Store the contents of the csv file into a list `records` where each element in the list is itself a list where the elements correspond to the `Parse%`,`Name`,`Amount`,`iLvL`,`iLvL%`,`Active Time`,`DPS` values for each line in the csv file.
# - Create an empty list called `player_name`.
# - iterate over each element of `records` appending the player names to `player_name`.
# - Print each name in `player_name` in alphabetical order.

# %%
import csv
with open('log_ex8.csv') as f:
  reader = csv.reader(f)
  records = [row for row in reader][1:]
  player_name = [i[1] for i in records]
  player_name.sort()

# %% [markdown]
# ## Exercise 8.6
#
# Download the file: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
#
# Write code to read and store the contents of this comma separated file within a 2D List, $L$, such that $L[i]$ corresponds to the sample entry on the $i$-th line of the file, and $L[i][j]$ corresponds to the $j$-th value of the $i$-th entry.
# Print the contents of the 2D List to verify that you have stored the contents correctly.

# %%
import csv
with open('iris.data') as f:
  reader = csv.reader(f)
  x = [None] + [[None] + for row in reader]
  
  for i in x:
    L.append([])

# L[1][1] = 5.1
# L = [None,[5.1,p]]
# Out:
#   File "<ipython-input-57-5283a5ee61dc>", line 4
#     [for row in reader]
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Exercise 8.7
#
# Each line in the file at: http://itu.dk/people/pagh/sad12/primes1000000.txt represents a prime number below 1,000,000.
#
# Write a function that uses the above file to test if a given positive integer below 1,000,000 is a prime number. If the given numbers exceeds 1,000,000, then utilise a separate function to calculate if it is a prime.

# %%
import math
def isPrime(n):
  if n<1000000:
    with open('primes1000000.txt','r') as f:
      for line in f:
        if n == int(line):
          return True
      return False
  else:
    if n%2 ==0:
      return False
    for i in range(3,math.ceil(math.sqrt(n))+1,2):
      if n%i ==0:
        return False
    return True

# %% [markdown]
# ## Exercise 8.8
#
# A mathematical equation $y=f(x)$ can be visualized on a cartesian plane as the set of all the points $(x,y)$ where $y=f(x)$. Write a code that
#
# 1. generates 100 points that satisfy the equation $y=x^2$ for $-10\leq x\leq 10$ (for simplicity, take the uniform spacing for the $x$-values of the points),and
# 2. saves them into a text file named `ex8_8.txt`. Each line in the file is of the form $(x,y)$,
# 3. load the points from `ex8_8.txt` and using the module `matplotlib`, show the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
xlist = np.linspace(-10,10,100)
f = lambda x: x**2
text = ''
for x in xlist:
  y = f(x)
  text+= f'({x},{y})\n'
print(text)
with open('ex8_8.txt','w') as f:
  f.write(text)

# %%
with open('ex8_8.txt') as f:
  str_coord = f.read().splitlines()
  print(str_coord)
  tup_coord = [eval(coords) for coords in str_coord]
  print(tup_coord)
  x_coord = [coords[0] for coords in tup_coord]
  y_coord = [coords[1] for coords in tup_coord]
  print(x_coord)
  plt.plot(x_coord,y_coord)
  plt.show
# Out:
# ['(-10.0,100.0)', '(-9.797979797979798,96.00040812162024)', '(-9.595959595959595,92.08244056728904)', '(-9.393939393939394,88.24609733700643)', '(-9.191919191919192,84.49137843077237)', '(-8.98989898989899,80.81828384858687)', '(-8.787878787878787,77.22681359044994)', '(-8.585858585858587,73.7169676563616)', '(-8.383838383838384,70.2887460463218)', '(-8.181818181818182,66.94214876033058)', '(-7.979797979797979,63.67717579838791)', '(-7.777777777777778,60.49382716049382)', '(-7.575757575757576,57.39210284664831)', '(-7.373737373737374,54.37200285685134)', '(-7.171717171717171,51.43352719110294)', '(-6.96969696969697,48.576675849403124)', '(-6.767676767676768,45.80144883175187)', '(-6.565656565656566,43.10784613814917)', '(-6.363636363636363,40.49586776859504)', '(-6.161616161616162,37.96551372308948)', '(-5.959595959595959,35.51678400163248)', '(-5.757575757575758,33.149678604224064)', '(-5.555555555555555,30.864197530864196)', '(-5.353535353535354,28.660340781552907)', '(-5.151515151515151,26.538108356290174)', '(-4.94949494949495,24.497500255076016)', '(-4.747474747474747,22.538516477910417)', '(-4.545454545454546,20.661157024793393)', '(-4.343434343434343,18.865421895724925)', '(-4.141414
# [-10.0, -9.797979797979798, -9.595959595959595, -9.393939393939394, -9.191919191919192, -8.98989898989899, -8.787878787878787, -8.585858585858587, -8.383838383838384, -8.181818181818182, -7.979797979797979, -7.777777777777778, -7.575757575757576, -7.373737373737374, -7.171717171717171, -6.96969696969697, -6.767676767676768, -6.565656565656566, -6.363636363636363, -6.161616161616162, -5.959595959595959, -5.757575757575758, -5.555555555555555, -5.353535353535354, -5.151515151515151, -4.94949494949495, -4.747474747474747, -4.545454545454546, -4.343434343434343, -4.141414141414142, -3.9393939393939394, -3.737373737373738, -3.5353535353535355, -3.333333333333333, -3.1313131313131315, -2.929292929292929, -2.7272727272727275, -2.525252525252525, -2.3232323232323235, -2.121212121212121, -1.9191919191919187, -1.717171717171718, -1.5151515151515156, -1.3131313131313131, -1.1111111111111107, -0.9090909090909101, -0.7070707070707076, -0.5050505050505052, -0.30303030303030276, -0.10101010101010033, 0.10101010101010033, 0.30303030303030276, 0.5050505050505052, 0.7070707070707076, 0.9090909090909083, 1.1111111111111107, 1.3131313131313131, 1.5151515151515156, 1.7171717171717162, 1.9191919191919187, 2.121212121212121, 2.3232323232323235, 2.525252525252524, 2.7272727272727266, 2.929292929292929, 3.1313131313131315, 3.333333333333334, 3.5353535353535346, 3.737373737373737, 3.9393939393939394, 4.141414141414142, 4.3434343434343425, 4.545454545454545, 4.747474747474747, 4.94949494949495, 5.1515151515151505, 5.353535353535353, 5.555555555555555, 5.757575757575758, 5.9595959595959584, 6.161616161616163, 6.363636363636363, 6.565656565656564, 6.767676767676768, 6.969696969696969, 7.171717171717173, 7.373737373737374, 7.575757575757574, 7.777777777777779, 7.979797979797979, 8.18181818181818, 8.383838383838384, 8.585858585858585, 8.787878787878789, 8.98989898989899, 9.19191919191919, 9.393939393939394, 9.595959595959595, 9.7979797979798, 10.0]

# %% [markdown]
# ## Exercise 8.9
#
# A text file, `NOI_24_RESULT.txt` contains the results of the medallist recipients for the 24th National Olympiad in Informatics.
#
# Write a code to:
#
# - read the data from the text file,
# - store the school name and medal counts in a Python dictionary `medal_count` where the school name is the key and the associated value is a tuple of the form `(GOLD, SILVER, BRONZE)`,
# - print out the top 5 school with the highest number of medals won, regardless of the medal type.

# %%
import csv
import pprint as pp

with open('NOI_24_RESULT.csv', 'r') as f:
    reader = csv.reader(f)
    Medals = ['Gold', 'Silver', 'Bronze']
    reader1 = [i[-1] for i in reader if i != []]
    reader1 = [' School Of Science And Technology, Singapore' if i == ' Singapore' else i for i in reader1]

    MedalCoords = [reader1.index(i) for i in Medals]

    GoldList = reader1[MedalCoords[0] + 1:MedalCoords[1]]
    Silverlist = reader1[MedalCoords[1] + 1:MedalCoords[2]]
    Bronzelist = reader1[MedalCoords[2] + 1:]
    MegaList = [GoldList, Silverlist, Bronzelist]

    schools = sorted(list(set([i for i in reader1 if i not in Medals])))

    medal_count = {sch: [0, 0, 0] for sch in schools}
    for i in range(len(MegaList)):
        for j in MegaList[i]:
            if j in medal_count:
                medal_count[j][i] += 1

    #m = {sch: medal_count[sch][0] * ('GOLD',) + medal_count[sch][1] * ('SILVER',) + medal_count[sch][2] * ('BRONZE',)
    #     for sch in medal_count}
    n = {sch: (medal_count[sch][0], medal_count[sch][1], medal_count[sch][2]) for sch in medal_count}
    pp.pprint(n)
    ranking = {sch: sum(medal_count[sch]) for sch in medal_count}
    x = sorted(ranking, key=lambda k: ranking[k], reverse=True)[:5]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4f44cb540dce> in <module>()
#       1 import csv
#       2 import pprint as pp
# ----> 3 with open('NOI_24_RESULT.csv', 'r') as f:
#       4   reader = csv.reader(f)
#       5   Medals = ['Gold','Silver','Bronze']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NOI_24_RESULT.csv'

# %% [markdown]
# ## Exercise 8.10
#
# A text file, `MARKET_PRICES.TXT`, contains the in-game prices for 6 items, Widowbloom, Rising Glory, Marrowroot, Vigil's Torch, Nighshade and Spectral Flask of Power from 1 December 2020 to 3 March 2021. Each line contains tab-delimited data that shows the date and the prices (in copper coins) of the 6 items.
#
# Each line is in the format:
#
#     `YYYY-MM-DD\tWIDOWBLOOM\tRISING_GLORY\t\MARROWROOT\tVIGILS_TORCH\tNIGHTSHADE\tSPECTRAL_FLASK_OF_POWER\n`
#
# - The date is of the form `YYYY-MM-DD`, for example, `2020-12-03` is 3rd December, 2020.
# - WIDOWBLOOM, RISING_GLORY, MARROWROOT, VIGILS_TORCH, NIGHTSHADE, SPECTRAL_FLASK_OF_POWER are all integers.
# - `\t` represents the tab character
# - `\n` represents the newline character
#
# The text file is stored in ascending order of date and time.
#
# ### Task 1
#
# Write a program to:
#
# - read the price data from the text file,
# - for each of the 6 items:
#     - find the highest price and print this value,
#     - find the lowest price and print this value.
#
# ### Task 2
#
# Suppose you want to play the market by buying and selling the 6 items above, one way to decide on items to invest in is by using the mean and variance of the daily rate of returns of the items. The latter is used to quantify the risk of holding such item.
#
# For an item $j$,
# - the **daily rate of return** of day $i$ to $i+1$, denoted as $r_i$ is defined to be $$r_i=\frac{p_{i+1}}{p_i},$$ where $p_{i+1}$ and $p_i$ are prices of the item on day $i+1$ and day $i$ respectively,
# - the mean of the daily rate of returns, denoted as $\overline{r}$, is just $\frac{\sum r_i}{n}$, where $n$ is the number of daily rate of returns recorded,
# - the variance of the daily rate of returns is $$\frac{\sum{(r_i-\overline{r})^2}}{n},$$ where $\overline{r}$ is the mean of the daily rate of returns and again $n$ is the number of daily returns recorded.
#
# Write a program to:
#
# - for each of the 6 items:
#     - find the mean of the daily rate of return,
#     - find the variance of the daily rate of return.

# %%
import csv
import statistics
with open('MARKET_PRICES.txt') as f:
    reader = csv.reader(f,delimiter = '\t')
    columns = next(reader)
    pricelist = []
    for i in range(1,7):
        f.seek(0)
        pricelist += [[int(row[i]) for row in reader if row[i] not in columns]]
    idk = dict(zip(columns[1:],pricelist))
    for k,v in idk.items():
        print(f'{k}: max:{max(v)}, min:{min(v)}')


    def dailyror(a):
        if len(a) == 2:
            return []
        else:
            return [(a[1]-a[0]) / a[0]] + dailyror(a[1:])


    def variance(data):
        n = len(data)
        mean = sum(data) / n
        deviations = [(x - mean) ** 2 for x in data]
        variance = sum(deviations) / n
        return variance
mdailyror = [statistics.mean(dailyror(price)) for price in pricelist]
print(mdailyror)
#x = (list(zip(columns[1:],mdailyror)
