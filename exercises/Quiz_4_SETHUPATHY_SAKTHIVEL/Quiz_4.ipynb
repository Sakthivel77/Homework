# %% [markdown]
# # Student Names
#
# 1. CAO JIALIN, MARIANNA
# 2. CHAY KA WENG, NICOLE
# 3. MERYL GRACE DANY
# 4. AQIL AHAMED
# 5. EDWARD THOMAS PATANI
# 6. GAN WEIXUAN, KEEGAN
# 7. HENG HONG LI
# 8. HUI HON YEUNG SHAWN
# 9. JAVIER KOH KAI HAN
# 10. JIANG BOHAN
# 11. KAI SATO
# 12. KEITH CHIA WEN KAI
# 13. MARCUS TAN WEI QI
# 14. NICHOLAS VUN KEN
# 15. RALPH YEO SAN REN
# 16. RUDOLF CHEAM YUE HAN
# 17. SETHUPATHY SAKTHIVEL
# 18. WONG GWUN YUEN AMBROSE

# %% [markdown]
# Please read the Honor Code below and acknowledge it by replacing `YOUR_NAME_HERE` with your registered names found in the previous cell. Do not use variant of your names that does not match the ones in the register.
#
# > I, <YOUR_NAME_HERE>, affirm my awareness of the standards of the Honor Code.
#
# # NJC Computing Honor Code
#
# Members of the college community commit themselves to producing academic work of integrity – that is, work that adheres to the scholarly and intellectual standards of accurate attribution of sources, appropriate collection and use of data, and transparent acknowledgement of the contribution of others to their ideas, discoveries, interpretations, and conclusions. Cheating on examinations, plagiarizing or misrepresenting the ideas or language of someone else as one’s own, falsifying data, or any other instance of academic dishonesty violates the standards of our community.

# %% [markdown]
# ## Task 4.1
#
# The text file, `exchange_rates.txt`, contains data items for a number of foreign currencies. Each data item is separated by a comma, with each currency's data on a new line as follows:
# - index
# - currency name
# - currency abbreviation
# - a float indicating the value in Singapore Dollar, $SGD
# - a float indicating the equivalent value of that currency againts $SGD value in the previous item
#
# The first 2 lines from the file are shown as follows:
#
# ```python
# > 0, US Dollar, USD
# > 1, Chinese Yuan, Renminbi, CNY, 1.0, 4.82844
# ```
#
# Write a Python program and the necessary files to create a web application that enables the equivalent value of user-inputted Singapore Dollar value  in various currencies (found in the text file) to be displayed. Therefore, there are at least 2 pages to be created.
# - one asking for the user input
# - another displaying the required information
#
# For each currency the web page should include the:
#
# - equivalent value in that currency of the user-inputted Singapore dollar value
# - country flag (flag files are included in the zip)
# - currency name abbreviation (e.g., USD for US dollars, JPY for Japanese Yen etc.)
#
#
# Save your program as
#
# >`Task4_1_<your name>.py`
#
# with any additional files/sub-folders as needed in a folder named
#
# >`TASK4_1_<your name>`
#
# <div style="text-align: right">[7]</div>
#
# Run the web application and save the output of the program as
#
# >`TASK4_1_<your name>.html`
#
# <div style="text-align: right">[3]</div>
